# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\rashi\Downloads\Data Analyst Boot Camp\Assignment Data\Assignment 3\airbnblistings.csv')

# %%
df
# Out:
#                 id                                               name  \
# 0     2.818000e+03           Quiet Garden View Room & Super Fast WiFi
# 1     2.016800e+04       Studio with private bathroom in the centre 1
# 2     2.788600e+04  Romantic, stylish B&B houseboat in canal district
# 3     2.887100e+04                            Comfortable double room
# 4     2.905100e+04                            Comfortable single room
# ...            ...                                                ...
# 6168  6.404540e+17                                       Villa Newbia
# 6169  6.405130e+17  Central | Clean | Cozy APT & Roof Terrace @ De...
# 6170  6.405250e+17   Central | Bright | Clean Studio w WiFi @ De Pijp
# 6171  6.410590e+17                     City centrum private studio 14
# 6172  6.411320e+17               Lovely one bedroom in Amsterdam Zuid
#
#         host_id  host_name  host_since_Year  \
# 0          3159     Daniel             2008
# ...

# %%
df.head(5)
# Out:
#         id                                               name  host_id  \
# 0   2818.0           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168.0       Studio with private bathroom in the centre 1    59484
# 2  27886.0  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871.0                            Comfortable double room   124245
# 4  29051.0                            Comfortable single room   124245
#
#    host_name  host_since_Year                           neighbourhood  \
# 0     Daniel             2008  Oostelijk Havengebied - Indische Buurt
# 1  Alexander             2009                            Centrum-Oost
# 2       Flip             2010                            Centrum-West
# 3      Edwin             2010                            Centrum-West
# 4      Edwin             2010                            Centrum-Oost
#
#    latitude  longitude     room_type  price  ...  last_review  \
# ...

# %%
#How many AirBnB listings are there in the city of Amsterdam?
df.count()
# Out:
# id                             6173
# name                           6173
# host_id                        6173
# host_name                      6173
# host_since_Year                6173
# neighbourhood                  6173
# latitude                       6173
# longitude                      6173
# room_type                      6173
# price                          6173
# minimum_nights                 6173
# number_of_reviews              6173
# last_review                    5583
# review_scores_rating           5583
# review_scores_accuracy         5575
# review_scores_cleanliness      5575
# review_scores_checkin          5575
# review_scores_communication    5575
# review_scores_location         5575
# review_scores_value            5575
# accommodates                   6173
# bedrooms                       5859
# dtype: int64

# %%
#What is the average price of all the AirBnB lisitngs in Amsterdam?
df['price'].mean()
# Out:
# 198.01960149036125

# %%
#What is the aveage rating received by all the AirBnB listings in Amsterdam?
df['review_scores_rating'].mean()
# Out:
# 4.800856170517622

# %%
#Plot a histogram for the following variables (price, number_of_reviews, and review_scores_ratings) and observe their distribution.
sns.histplot(data = df, x = "price", bins = 20)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
sns.histplot(data = df, x = "number_of_reviews", bins = 20)
# Out:
# <AxesSubplot:xlabel='number_of_reviews', ylabel='Count'>

# %%
sns.histplot(data = df, x = "review_scores_rating", bins = 20)
# Out:
# <AxesSubplot:xlabel='review_scores_rating', ylabel='Count'>

# %%
# Write your code here for plotting the distributuion of price.
df['price'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Write your code here for plotting the distribution of  reviews.
df['number_of_reviews'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Write your code here for plotting the distribution of ratings.
df['review_scores_rating'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Plot a visualization to show the number of listings for each room_type. Which room has the highest number of listings?
sns.histplot(data = df, x = "room_type", bins = 20)
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='Count'>

# %%
# You want to observe the relationship between the reviews(given by number of reviews) and the ratings received (review scores rating). Plot both a scatterplot and a jointplot. What can you say about the relationship?
sns.regplot('review_scores_rating', 'number_of_reviews', data = df)
# Out:
# C:\Users\rashi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='review_scores_rating', ylabel='number_of_reviews'>

# %%
sns.jointplot(x = "review_scores_rating", y = "number_of_reviews", data = df)

# %%
# The high score ratings seem to be in the smaller number of reviews.

# %%
# AirBnB has been adding quite a few listings in the city of Amsterdam since they started operating in 2008. Plot a lineplot to observe how the average review score 'review_score_rating' has changed across the different years.
sns.lineplot(data = df, x = 'host_since_Year', y = 'review_scores_rating')
# Out:
# <AxesSubplot:xlabel='host_since_Year', ylabel='review_scores_rating'>

# %%
#The review scores have been trending downward since 2008 with a sharp drop of review scoreds in 2009.

# %%
# You wish to identify the relationship between the various ratings each of the listings has received from the customer. Plot a heatmap of the correlations matrix of the ratings variables and document your observations.
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
#Analuze the listings prices across the following neighborhoods using a categorical boxplot (Westerpark, Oud-Noord, Noord-West, Zuid).

#Write your code for subsetting the data for only the above neighborhoods here.
df1 = df[['price','neighbourhood']]
df1
# Out:
#       price                           neighbourhood
# 0        49  Oostelijk Havengebied - Indische Buurt
# 1       106                            Centrum-Oost
# 2       126                            Centrum-West
# 3        75                            Centrum-West
# 4        55                            Centrum-Oost
# ...     ...                                     ...
# 6168    610                            Centrum-Oost
# 6169    109                 De Pijp - Rivierenbuurt
# 6170    109                 De Pijp - Rivierenbuurt
# 6171     94                            Centrum-West
# 6172     85                                    Zuid
#
# [6173 rows x 2 columns]

# %%
# Write your code for plotting the categorical boxplot here.

sns.boxplot(x = 'price', y = 'neighbourhood',data = df1)
# Out:
# <AxesSubplot:xlabel='price', ylabel='neighbourhood'>
